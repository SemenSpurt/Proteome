# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import os 
os.getcwd()
# Out:
# '/home/selezov_su/notebooks/Promics/Panoram'

# %%
import gseapy as gp

names = gp.get_library_name(organism='Human')
names;

# %%
with open("Data/only_pneumonia.txt", "r") as file:
    proteins = file.read().splitlines()


from UniProtMapper import ProtMapper

mapper = ProtMapper()

result, failed = mapper.get(
    ids=proteins, from_db="UniProtKB_AC-ID", to_db="GeneID"
)

with open("Data/only_pneumonia_gene_set.txt", 'w') as file:
    file.write("\n".join(result["To"].to_list()))
# Out:
# WARNING:root:Custom fields not available when querying GeneID.
# Setting fields to `None` to retrieve all available fields...
# Fetched: 16 / 16

# %%
with open("Data/de_proteins.txt", "r") as file:
    proteins = file.read().splitlines() 


from UniProtMapper import ProtMapper

mapper = ProtMapper()

result, failed = mapper.get(
    ids=proteins, from_db="UniProtKB_AC-ID", to_db="GeneID"
)

with open("Data/de_gene_set.txt", 'w') as file:
    file.write("\n".join(result["To"].to_list()))
# Out:
# WARNING:root:Custom fields not available when querying GeneID.
# Setting fields to `None` to retrieve all available fields...
# Fetched: 8 / 8

# %%
with open("Data/whole_protein_set.txt", "r") as file:
    proteins = file.read().splitlines() 


from UniProtMapper import ProtMapper

mapper = ProtMapper()

result, failed = mapper.get(
    ids=proteins, from_db="UniProtKB_AC-ID", to_db="Gene_Name"
)

with open("Data/whole_gene_set.txt", 'w') as file:
    file.write("\n".join(result["To"].to_list()))
# Out:
# WARNING:root:Custom fields not available when querying Gene_Name.
# Setting fields to `None` to retrieve all available fields...
# Fetched: 98 / 98

# %%
import gseapy as gp
go_mf = gp.get_library(name='GO_Cellular_Component_2021', organism='Human')

# if you are only intrested in dataframe that enrichr returned, please set outdir=None
enr = gp.enrichr(
    gene_list=result["To"].to_list(), # or "./tests/data/gene_list.txt",
    gene_sets=['GO_Biological_Process_2023', 'GO_Molecular_Function_2023', "GO_Cellular_Component_2023"],
    organism='human', # don't forget to set organism to the one you desired!␣˓→e.g. Yeast
    # background=None,
    outdir=None, # don't write to disk
    cutoff=0.05
)
enr.results


# categorical scatterplot
ax = gp.barplot(
    enr.results,
    # title = "Gene ontology",
    column="P-value",
    group='Gene_set', # set group, so you could do a multi-sample/library comparsion
    size=5,
    top_term=5,
    figsize=(3,8),
    #color=['darkred', 'darkblue'] # set colors for group
    color = {
        'GO_Biological_Process_2021': 'red', 
        'GO_Molecular_Function_2021':'salmon',
        "GO_Cellular_Component_2021" : "blue",
        # "KEGG_2021_Human" : "red",
    }
)
ax.figure.savefig("Plots/go_barplot.png", bbox_inches="tight", dpi=200)

# %%
import gseapy as gp
go_mf = gp.get_library(name='GO_Cellular_Component_2023', organism='Human')

# if you are only intrested in dataframe that enrichr returned, please set outdir=None
enr = gp.enrichr(
    gene_list=result["To"].to_list(), # or "./tests/data/gene_list.txt",
    gene_sets=['GO_Biological_Process_2023'],
    organism='human', # don't forget to set organism to the one you desired!␣˓→e.g. Yeast
    # background=None,
    outdir=None, # don't write to disk
    cutoff=0.05
)

enr.results


# simple plotting function
from gseapy import barplot, dotplot

# categorical scatterplot
ax = dotplot(
    enr.results,
    column="P-value",
    x="Gene set", # set x axis, so you could do a multi-sample/library comparsion
    size=10,
    top_term=15,
    figsize=(3,8),
    # title = "Gene ontology",
    xticklabels_rot=45, # rotate xtick labels
    show_ring=True, # set to False to revmove outer ring
    marker='o',
    cmap="bwr",
)
ax.figure.savefig("Plots/go_dotplot.png", bbox_inches="tight", dpi=200)

# %%
tissues = pd.read_csv("normal_tissue.tsv", sep="\t").iloc[:-1]
# t = tissues.loc[tissues["Tissue"] == "nasopharynx"][["Cell type", "Gene name"]]
t = tissues[["Cell type", "Gene name"]]

# gene_sets = dict((typ, t.loc[t["Cell type"] == typ]["Gene name"].to_list()) for typ in t["Cell type"].drop_duplicates())
gene_sets = dict((typ, t.loc[t["Cell type"] == typ]["Gene name"].to_list()) for typ in t["Cell type"].drop_duplicates())

enr2 = gp.enrich(
    gene_list="Data/whole_gene_set.txt", # or gene_list=glist
    gene_sets=gene_sets, # kegg is a dict object
    background=None, # or "hsapiens_gene_ensembl", or int, or text file, or a list of genes
    outdir=None,
    verbose=True
)
# Out:
# 2024-09-30 10:51:23,219 [INFO] Input dict object named with gs_ind_0
# 2024-09-30 10:51:23,222 [INFO] Run: gs_ind_0
# 2024-09-30 10:51:23,288 [INFO] Background is not set! Use all 9685 genes in gs_ind_0.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3811577/958166913.py in <module>
#       6 gene_sets = dict((typ, t.loc[t["Cell type"] == typ]["Gene name"].to_list()) for typ in t["Cell type"].drop_duplicates())
#       7
# ----> 8 enr2 = gp.enrich(
#       9     gene_list="Data/whole_gene_set.txt", # or gene_list=glist
#      10     gene_sets=gene_sets, # kegg is a dict object
#
# /home/tools/anaconda3/lib/python3.9/site-packages/gseapy/__init__.py in enrich(gene_list, gene_sets, background, outdir, cutoff, format, figsize, top_term, no_plot, verbose)
#     650     # set organism
#     651     enr.set_organism()
# --> 652     enr.run()
#     653
#     654     return enr
#
# /home/tools/anaconda3/lib/python3.9/site-packages/gseapy/enrichr.py in run(self)
#     592                 if self._isezid:
#     593                     g = {k: list(map(int, v)) for k, v in g.items()}
# --> 594                 res = self.enrich(g)
#     595                 if res is None:
#     596                     self._logger.info(
#
# /home/tools/anaconda3/lib/python3.9/site-packages/gseapy/enrichr.py in enrich(self, gmt)
#     541         bg = self.parse_background(gmt)
#     542         # statistical testing
# --> 543         hgtest = list(calc_pvalues(query=self._gls, gene_sets=gmt, background=bg))
#     544         if len(hgtest) > 0:
#     545             terms, pvals, oddr, olsz, gsetsz, genes = hgtest
#
# /home/tools/anaconda3/lib/python3.9/site-packages/gseapy/stats.py in calc_pvalues(query, gene_sets, background, **kwargs)
#      71     k = len(query)
#      72     # pval
# ---> 73     subsets = sorted(gene_sets.keys())
#      74     for s in subsets:
#      75         category = set(gene_sets.get(s))
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
enr2

# %%
enr2.results2
# Out:
#    Gene_set                               Term  Overlap   P-value  \
# 0  gs_ind_0                        basal cells   6/1209  0.611016
# 1  gs_ind_0         ciliated cells (cell body)   6/1195  0.599057
# 2  gs_ind_0     ciliated cells (cilia axoneme)   6/1153  0.562168
# 3  gs_ind_0  ciliated cells (ciliary rootlets)   6/1166  0.573741
# 4  gs_ind_0      ciliated cells (tip of cilia)   6/1152  0.561273
# 5  gs_ind_0                       goblet cells   5/1121  0.706697
# 6  gs_ind_0       respiratory epithelial cells  42/8045  0.559909
#
#    Adjusted P-value  Odds Ratio  Combined Score  \
# 0          0.706697    1.017087        0.501050
# 1          0.706697    1.030858        0.528209
# 2          0.706697    1.074187        0.618683
# 3          0.706697    1.060440        0.589157
# 4          0.706697    1.075257        0.621013
# 5          0.706697    0.916200        0.318062
# 6          0.706697    0.983200        0.570237
#
#                                                Genes
# 0                EZR;PRDX2;HSP90AA1;GAPDH;DHX33;ENO1
# 1                EZR;PRDX2;HSP90AA1;GAPDH;DHX33;ENO1
# 2                EZR;PRDX2;HSP90AA1;GAPDH;DHX33;ENO1
# 3                EZR;PRDX2;HSP90AA1;GAPDH;DHX33;ENO1
# 4                EZR;PRDX2;HSP90AA1;GAPDH;DHX33;ENO1
# 5                         EZR;PRDX2;GAPDH;DHX33;ENO1
# 6  SCGB1A1;CAP1;VTN;AZGP1;TUBA1B;CST4;SERPINB1;LD...

# %%
import gseapy as gp
go_mf = gp.get_library(name='GO_Cellular_Component_2023', organism='Human')

# if you are only intrested in dataframe that enrichr returned, please set outdir=None
enr = gp.enrichr(
    gene_list=result["To"].to_list(), # or "./tests/data/gene_list.txt",
    gene_sets=['GO_Biological_Process_2023'],
    organism='human', # don't forget to set organism to the one you desired!␣˓→e.g. Yeast
    # background=None,
    outdir=None, # don't write to disk
)

enr.results


# simple plotting function
from gseapy import barplot, dotplot

# categorical scatterplot
ax = dotplot(
    enr.results,
    column="P-value",
    x="Gene set", # set x axis, so you could do a multi-sample/library comparsion
    size=10,
    top_term=15,
    figsize=(3,8),
    title = "Gene ontology",
    xticklabels_rot=45, # rotate xtick labels
    show_ring=True, # set to False to revmove outer ring
    marker='o',
    cmap="bwr",
)
ax.figure.savefig("Plots/go_dotplot.png", bbox_inches="tight", dpi=200)

# %%
from gseapy import heatmap


# plotting heatmap
i = 2
genes = gs_res.res2d.Lead_genes[i].split(";")
# Make sure that ``ofname`` is not None, if you want to save your figure to disk
ax = heatmap(df = gs_res.heatmat.loc[genes], z_score=0, title=terms[i], figsize=(14,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3811577/966536027.py in <module>
#       4 # plotting heatmap
#       5 i = 2
# ----> 6 genes = gs_res.res2d.Lead_genes[i].split(";")
#       7 # Make sure that ``ofname`` is not None, if you want to save your figure to disk
#       8 ax = heatmap(df = gs_res.heatmat.loc[genes], z_score=0, title=terms[i], figsize=(14,4))
#
# NameError: name 'gs_res' is not defined
